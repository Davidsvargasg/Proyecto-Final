# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Jugadores reales

# %%
df_u21 = pd.read_csv("../Datos/real_players_u21.csv")

# %%
# Asignar un ID basado en el índice de cada fila
df_u21['player_id'] = range(1, len(df_u21) + 1)

# Verificar los resultados
df_u21
# Out:
#                 Player  Age     Nat.                         Club  \
# 0      Jude Bellingham   21  England                  Real Madrid
# 1        Florian Wirtz   21  Germany          Bayer 04 Leverkusen
# 2        Jamal Musiala   21  Germany                Bayern Munich
# 3         Lamine Yamal   17    Spain                 FC Barcelona
# 4    Eduardo Camavinga   21   France                  Real Madrid
# ..                 ...  ...      ...                          ...
# 345   Dexter Lembikisa   20  Jamaica  Wolverhampton Wanderers U21
# 346        Anton Gaaei   21  Denmark               Ajax Amsterdam
# 347    Nikita Saltykov   20   Russia             Lokomotiv Moscow
# 348   Aljoscha Kemlein   20  Germany            1.FC Union Berlin
# 349      Robert Wagner   21  Germany                 FC St. Pauli
#
#      Market value  minutes_played  goals  assists  position   foot  \
# 0           180.0         13820.0   47.0     38.0  Midfield  right
# 1           130.0         10929.0   41.0     50.0  Midfield  right
# 2           130.0          9175.0   43.0     31.0  Midfield  right
# 3           120.0          2964.0    7.0      9.0    Attack   left
# 4           100.0         13733.0    4.0     13.0  Midfield   left
# ..            ...             ...    ...      ...       ...    ...
# 345           3.0          1176.0    1.0      0.0  Defender  right
# 346           3.0          4030.0    2.0      9.0  Defender  right
# 347           3.0          2556.0    4.0      5.0    Attack  right
# 348           3.0           108.0    0.0      0.0  Midfield  right
# 349           3.0           124.0    0.0      0.0  Midfield  right
#
#      height_in_cm  player_id
# 0           186.0          1
# 1           177.0          2
# 2           184.0          3
# 3           180.0          4
# 4           182.0          5
# ..            ...        ...
# 345         180.0        346
# 346         183.0        347
# 347         174.0        348
# 348         185.0        349
# 349         181.0        350
#
# [350 rows x 12 columns]

# %%
info_jugadores = df_u21 [['player_id', 'Player', 'Club', 'position', 'Market value', 'Nat.']]
info_jugadores
# Out:
#      player_id             Player                         Club  position  \
# 0            1    Jude Bellingham                  Real Madrid  Midfield
# 1            2      Florian Wirtz          Bayer 04 Leverkusen  Midfield
# 2            3      Jamal Musiala                Bayern Munich  Midfield
# 3            4       Lamine Yamal                 FC Barcelona    Attack
# 4            5  Eduardo Camavinga                  Real Madrid  Midfield
# ..         ...                ...                          ...       ...
# 345        346   Dexter Lembikisa  Wolverhampton Wanderers U21  Defender
# 346        347        Anton Gaaei               Ajax Amsterdam  Defender
# 347        348    Nikita Saltykov             Lokomotiv Moscow    Attack
# 348        349   Aljoscha Kemlein            1.FC Union Berlin  Midfield
# 349        350      Robert Wagner                 FC St. Pauli  Midfield
#
#      Market value     Nat.
# 0           180.0  England
# 1           130.0  Germany
# 2           130.0  Germany
# 3           120.0    Spain
# 4           100.0   France
# ..            ...      ...
# 345           3.0  Jamaica
# 346           3.0  Denmark
# 347           3.0   Russia
# 348           3.0  Germany
# 349           3.0  Germany
#
# [350 rows x 6 columns]

# %%
caracteristicas_jugadores = df_u21 [['player_id', 'foot', 'height_in_cm']]
caracteristicas_jugadores
# Out:
#      player_id   foot  height_in_cm
# 0            1  right         186.0
# 1            2  right         177.0
# 2            3  right         184.0
# 3            4   left         180.0
# 4            5   left         182.0
# ..         ...    ...           ...
# 345        346  right         180.0
# 346        347  right         183.0
# 347        348  right         174.0
# 348        349  right         185.0
# 349        350  right         181.0
#
# [350 rows x 3 columns]

# %%
estadisticas_jugadores = df_u21 [['player_id', 'minutes_played', 'goals', 'assists']]
estadisticas_jugadores
# Out:
#      player_id  minutes_played  goals  assists
# 0            1         13820.0   47.0     38.0
# 1            2         10929.0   41.0     50.0
# 2            3          9175.0   43.0     31.0
# 3            4          2964.0    7.0      9.0
# 4            5         13733.0    4.0     13.0
# ..         ...             ...    ...      ...
# 345        346          1176.0    1.0      0.0
# 346        347          4030.0    2.0      9.0
# 347        348          2556.0    4.0      5.0
# 348        349           108.0    0.0      0.0
# 349        350           124.0    0.0      0.0
#
# [350 rows x 4 columns]

# %% [markdown]
# ## Exportar a SQL

# %%
# Código usado para e enviar a SQL los df

import pandas as pd
import pymysql
from sqlalchemy import create_engine
import getpass

#Obtener la contraseña del usuario
password = getpass.getpass(prompt='Enter your MySQL password: ')

# Nombre de la base de datos
bd = "Trabajo_final"

# Crear la cadena de conexión
connection_string = f'mysql+pymysql://root:{password}@localhost/{bd}'

# Crear el motor de conexión
engine = create_engine(connection_string)

# Enviar DataFrames a la base de datos
info_jugadores.to_sql('info_jugadores', con=engine, if_exists='replace', index=False)
caracteristicas_jugadores.to_sql('caracteristicas_jugadores', con=engine, if_exists='replace', index=False)
estadisticas_jugadores.to_sql('estadisticas_jugadores', con=engine, if_exists='replace', index=False)

print("DataFrames enviados a la base de datos exitosamente.")
# Out:
# DataFrames enviados a la base de datos exitosamente.

# %%
df_u21_fifa = pd.read_csv("../Datos/fifa_players_u21.csv")

# %%
# Asignar un ID basado en el índice de cada fila
df_u21_fifa['player_id'] = range(1, len(df_u21_fifa) + 1)

# Verificar los resultados
df_u21_fifa
# Out:
#                               name       nation position  age  overall  \
# 0                    Jamal Musiala      Germany      CAM   20       86
# 1                  Jude Bellingham      England      CAM   20       88
# 2                    Florian Wirtz      Germany      CAM   20       87
# 3             Pedro González López        Spain       CM   20       86
# 4                      Bukayo Saka      England       RW   21       86
# ...                            ...          ...      ...  ...      ...
# 1995           Thimothée Lo-Tutala       France       GK   20       63
# 1996           Manuel Morillo León        Spain       ST   19       62
# 1997  Antonino Jastin García López     Portugal       LM   19       62
# 1998           Iker Almena Horcajo        Spain       RM   19       62
# 1999                Gjivai Zechiël  Netherlands       CM   19       62
#
#       potential  total_gk  total_stats  pace  shooting  passing  dribbling  \
# 0            93        42         2090    85        75       76         91
# 1            92        48         2295    80        83       81         87
# 2            92        57         2089    80        76       86         88
# 3            92        46         2138    78        69       82         88
# 4            90        50         2196    85        82       81         88
# ...         ...       ...          ...   ...       ...      ...        ...
# 1995         75       314          918    64        62       61         67
# 1996         79        59         1502    76        61       51         65
# 1997         78        47         1439    77        55       53         65
# 1998         80        51         1450    74        54       56         63
# 1999         80        40         1687    75        47       59         67
#
#       defending  physical                 team  altura   foot   cost  \
# 0            63        61    FC Bayern München     184  Right  134.5
# 1            78        83          Real Madrid     186  Right  128.5
# 2            50        63  Bayer 04 Leverkusen     177  Right  118.5
# 3            70        74         FC Barcelona     174  Right  105.0
# 4            60        70              Arsenal     178   Left   99.0
# ...         ...       ...                  ...     ...    ...    ...
# 1995         21        60     Doncaster Rovers     186  Right    1.0
# 1996         21        47           Real Betis     182  Right    1.0
# 1997         23        43               Girona     180  Right    1.0
# 1998         25        46               Girona     176   Left    1.0
# 1999         62        52            Feyenoord     183  Right    1.0
#
#       player_id
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
# ...         ...
# 1995       1996
# 1996       1997
# 1997       1998
# 1998       1999
# 1999       2000
#
# [2000 rows x 19 columns]

# %%
fifa_info_jugadores = df_u21_fifa [['player_id', 'name', 'team', 'position', 'nation', 'cost']]
fifa_info_jugadores
# Out:
#       player_id                          name                 team position  \
# 0             1                 Jamal Musiala    FC Bayern München      CAM
# 1             2               Jude Bellingham          Real Madrid      CAM
# 2             3                 Florian Wirtz  Bayer 04 Leverkusen      CAM
# 3             4          Pedro González López         FC Barcelona       CM
# 4             5                   Bukayo Saka              Arsenal       RW
# ...         ...                           ...                  ...      ...
# 1995       1996           Thimothée Lo-Tutala     Doncaster Rovers       GK
# 1996       1997           Manuel Morillo León           Real Betis       ST
# 1997       1998  Antonino Jastin García López               Girona       LM
# 1998       1999           Iker Almena Horcajo               Girona       RM
# 1999       2000                Gjivai Zechiël            Feyenoord       CM
#
#            nation   cost
# 0         Germany  134.5
# 1         England  128.5
# 2         Germany  118.5
# 3           Spain  105.0
# 4         England   99.0
# ...           ...    ...
# 1995       France    1.0
# 1996        Spain    1.0
# 1997     Portugal    1.0
# 1998        Spain    1.0
# 1999  Netherlands    1.0
#
# [2000 rows x 6 columns]

# %%
fifa_caracteristicas_jugadores = df_u21_fifa [['player_id', 'foot', 'altura', 'age']]
fifa_caracteristicas_jugadores
# Out:
#       player_id   foot  altura  age
# 0             1  Right     184   20
# 1             2  Right     186   20
# 2             3  Right     177   20
# 3             4  Right     174   20
# 4             5   Left     178   21
# ...         ...    ...     ...  ...
# 1995       1996  Right     186   20
# 1996       1997  Right     182   19
# 1997       1998  Right     180   19
# 1998       1999   Left     176   19
# 1999       2000  Right     183   19
#
# [2000 rows x 4 columns]

# %%
fifa_estadisticas_jugadores = df_u21_fifa [['player_id', 'potential', 'total_gk', 'overall','total_stats', 'pace', 'shooting', 'passing', 'dribbling', 'defending','physical']]
fifa_estadisticas_jugadores
# Out:
#       player_id  potential  total_gk  overall  total_stats  pace  shooting  \
# 0             1         93        42       86         2090    85        75
# 1             2         92        48       88         2295    80        83
# 2             3         92        57       87         2089    80        76
# 3             4         92        46       86         2138    78        69
# 4             5         90        50       86         2196    85        82
# ...         ...        ...       ...      ...          ...   ...       ...
# 1995       1996         75       314       63          918    64        62
# 1996       1997         79        59       62         1502    76        61
# 1997       1998         78        47       62         1439    77        55
# 1998       1999         80        51       62         1450    74        54
# 1999       2000         80        40       62         1687    75        47
#
#       passing  dribbling  defending  physical
# 0          76         91         63        61
# 1          81         87         78        83
# 2          86         88         50        63
# 3          82         88         70        74
# 4          81         88         60        70
# ...       ...        ...        ...       ...
# 1995       61         67         21        60
# 1996       51         65         21        47
# 1997       53         65         23        43
# 1998       56         63         25        46
# 1999       59         67         62        52
#
# [2000 rows x 11 columns]

# %%
# Código usado para e enviar a SQL los df

import pandas as pd
import pymysql
from sqlalchemy import create_engine
import getpass

#Obtener la contraseña del usuario
password = getpass.getpass(prompt='Enter your MySQL password: ')

# Nombre de la base de datos
bd = "Trabajo_fifa"

# Crear la cadena de conexión
connection_string = f'mysql+pymysql://root:{password}@localhost/{bd}'

# Crear el motor de conexión
engine = create_engine(connection_string)

# Enviar DataFrames a la base de datos
fifa_info_jugadores.to_sql('info_jugadores', con=engine, if_exists='replace', index=False)
fifa_caracteristicas_jugadores.to_sql('caracteristicas_jugadores', con=engine, if_exists='replace', index=False)
fifa_estadisticas_jugadores.to_sql('estadisticas_jugadores', con=engine, if_exists='replace', index=False)

print("DataFrames enviados a la base de datos exitosamente.")
# Out:
# DataFrames enviados a la base de datos exitosamente.
